# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaki1203/Diwali-Sales-Project-using-Python/blob/main/Diwali_Sales_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/Diwali Sales Data.csv",encoding='unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.isna().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.rename(columns={'Cust_name':'Customer Name'},inplace=True)
df
# Out:
#        User_ID Customer Name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903     Sanskriti  P00125942      F     26-35   28               0
# 1      1000732        Kartik  P00110942      F     26-35   35               1
# 2      1001990         Bindu  P00118542      F     26-35   35               1
# 3      1001425        Sudevi  P00237842      M      0-17   16               0
# 4      1000588          Joni  P00057942      M     26-35   28               1
# ...        ...           ...        ...    ...       ...  ...             ...
# 11246  1000695       Manning  P00296942      M     18-25   19               1
# 11247  1004089   Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209         Oshin  P00201342      F     36-45   40               0
# 11249  1004023        Noonan  P00059442      M     36-45   37               0
# 11250  1002744       Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df["Amount"]=df["Amount"].fillna(0)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28      unmarried
# 1      1000732       Kartik  P00110942      F     26-35   35        married
# 2      1001990        Bindu  P00118542      F     26-35   35        married
# 3      1001425       Sudevi  P00237842      M      0-17   16      unmarried
# 4      1000588         Joni  P00057942      M     26-35   28        married
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942      M     18-25   19        married
# 11247  1004089  Reichenbach  P00171342      M     26-35   33      unmarried
# 11248  1001209        Oshin  P00201342      F     36-45   40      unmarried
# 11249  1004023       Noonan  P00059442      M     36-45   37      unmarried
# 11250  1002744      Brumley  P00281742      F     18-25   19      unmarried
#
# ...

# %%
df["Marital_Status"]=df["Marital_Status"].replace([0,1],['unmarried','married'])
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28      unmarried
# 1      1000732       Kartik  P00110942      F     26-35   35        married
# 2      1001990        Bindu  P00118542      F     26-35   35        married
# 3      1001425       Sudevi  P00237842      M      0-17   16      unmarried
# 4      1000588         Joni  P00057942      M     26-35   28        married
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942      M     18-25   19        married
# 11247  1004089  Reichenbach  P00171342      M     26-35   33      unmarried
# 11248  1001209        Oshin  P00201342      F     36-45   40      unmarried
# 11249  1004023       Noonan  P00059442      M     36-45   37      unmarried
# 11250  1002744      Brumley  P00281742      F     18-25   19      unmarried
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.125100e+04  11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207      2.489290   9443.527902
# std    1.716125e+03     12.754122      1.115047   5228.684037
# min    1.000001e+06     12.000000      1.000000      0.000000
# 25%    1.001492e+06     27.000000      1.500000   5440.000000
# 50%    1.003065e+06     33.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000      4.000000  23952.000000

# %%
df["Amount"]=df["Amount"].astype(int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-9fa0f91b4ea2> in <cell line: 1>()
# ----> 1 df["Amount"]=df["Amount"].astype(int64)
#
# NameError: name 'int64' is not defined

# %%
ax=sns.countplot(x='Gender',data=df)

for bar in ax.containers:
  ax.bar_label(bar)

# %%
df.groupby(["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
sales_gender=df.groupby(["Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(x='Gender'='Amount',data=sales_gender)
plt.title('Gender Vs Amount')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# *From above graphs we can see that most of the buyers are females and even the purchasing power of female are greater than male*

# %%
ax=sns.countplot(x='Age Group',hue='Gender',data=df)
plt.title('Age Group Vs Gender')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_age=df.groupby(["Age Group"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sales_age
# Out:
#   Age Group       Amount
# 2     26-35  42613443.94
# 3     36-45  22144995.49
# 1     18-25  17240732.00
# 4     46-50   9207844.00
# 5     51-55   8261477.00
# 6       55+   4080987.00
# 0      0-17   2699653.00

# %%
sales_age=df.groupby(["Age Group"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)

sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# From the above graph we can see that most of the buyers are from the age group of 26-35 females

# %%
sales_state=df.groupby(["State"],as_index=False)["Orders"].sum().sort_values(by="Orders",ascending=False).head(10)
plt.title('State Vs Orders',fontsize=20)
sns.barplot(x='State',y='Orders',data=sales_state,color='green')
sns.set(rc={'figure.figsize':(20,7)})

# %% [markdown]
# From above graph we can see that unexpectedly most of the orders are from Uttar Pradesh,Maharashtra and Karnataka but total sales/amount is from UP,Karnataka and Maharashtra

# %%
plt.title('Marital Status Count',fontsize=20)
ax=sns.countplot(data=df,x='Marital_Status')
sns.set(rc={'figure.figsize':(7,5)})

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_state=df.groupby(["Marital_Status","Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sales_state
# Out:
#   Marital_Status Gender       Amount
# 2      unmarried      F  43786648.44
# 0        married      F  30549207.99
# 3      unmarried      M  18338738.00
# 1        married      M  13574538.00

# %%
sales_state=df.groupby(["Marital_Status","Gender"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sns.barplot(data=sales_state,x='Marital_Status',y='Amount',hue='Gender')
sns.set(rc={'figure.figsize':(6,5)})

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(20,5)})
plt.title('Product Category',fontsize=20)
ax=sns.countplot(data=df,x='Occupation')
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_occupation=df.groupby(["Occupation"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
sales_occupation
# Out:
#          Occupation       Amount
# 10        IT Sector  14755079.00
# 8        Healthcare  13034587.49
# 2          Aviation  12602298.00
# 3           Banking  10770610.95
# 7              Govt   8517212.00
# 9       Hospitality   6376405.00
# 12            Media   6295832.99
# 1        Automobile   5368596.00
# 4          Chemical   5297436.00
# 11           Lawyer   4981665.00
# 13           Retail   4783170.00
# 6   Food Processing   4070670.00
# 5      Construction   3597511.00
# 14          Textile   3204972.00
# 0       Agriculture   2593087.00

# %%
sales_occupation=df.groupby(["Occupation"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False)
plt.title('Occupation Vs Amount',fontsize=20)
sns.set(rc={'figure.figsize':(23,10)})
sns.barplot(data=sales_occupation,x='Occupation',y='Amount')
# Out:
# <Axes: title={'center': 'Occupation Vs Amount'}, xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From the above graph we can see that most of the buyers are working in IT,Aviation and Healthcare

# %%
sales_product=df.groupby(["Product_Category"],as_index=False)["Amount"].sum().sort_values(by="Amount",ascending=False).head(10)
plt.title('Product_Category Vs Amount',fontsize=20)
sns.set(rc={'figure.figsize':(23,5)})
sns.barplot(data=sales_product,x='Product_Category',y='Amount')
# Out:
# <Axes: title={'center': 'Product_Category Vs Amount'}, xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From the above graph we can see that most of the sold products are from food, Clothings,Electronics and Footwear Category

# %% [markdown]
# **Conclusion**
#
# Married woman age group 26-35yrs From UP, MH, KA working in IT, Aviation and Healthcare are mostly likely to buy products from Food,Cloth,Electronics and Footwear Category
